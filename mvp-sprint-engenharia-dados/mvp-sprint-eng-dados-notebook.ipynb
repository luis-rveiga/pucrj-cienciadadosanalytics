# %% [markdown]
# # Trabalho da disciplina Projeto/MVP em Engenharia de Dados

# %% [markdown]
# ## Aluno: Luis Eduardo Ribeiro Veiga - RA: 40520223000855

# %% [markdown]
# **Descrição do Problema** - Construir um pipeline de dados utilizando tecnologias na nuvem. O pipeline irá envolver a busca, coleta, modelagem, carga e análise dos dados.

# %% [markdown]
# **Objetivo** - O objetivo do trabalho é montar um repositório que permita obter informações sobre taxas de evasão, repetência e promoção de alunos matriculados no ensino fundamental e médio nos vários municípios do Brasil - apesar da taxa de migração para EJA estar presente no repositório, o mesmo não será considerado na avaliação. O período de cobertura compreenderá os anos 2014 até 2019. Para enriquecer a análise serão incluídos na base de avaliação dados referentes ao PIB per-carpita e o repasse do programa Bolsa Família aos municípios.

# %% [markdown]
# ### Busca pelos dados
#
# Seguem abaixo os conjuntos de dados utilizados no trabalho.
#
# **Dados do Bolsa Família** - https://dados.gov.br/dados/conjuntos-dados/bolsa-familia---mi-social
#
# Esse conjunto de dados informa a quantidade de famílias beneficiárias e o valor repassado através da folha de pagamento do Bolsa Família, assim como o município e ano/mês de referência.
#
# Nesse conjunto de dados temos as seguintes variáveis:
#
# De 2004 a 2021:
#
# ibge : código ibge do município
# anomes : ano e mês de referência
# qtd_familias_beneficiarias_bolsa_familia : Quantidade de famílias beneficiárias do Programa Bolsa Família
# valor_repassado_bolsa_familia : Valor repassado para pagamento de benefícios do Programa Bolsa Família
#
# Licença: Creative Commons Atribuição
#
#
# **Taxas de Transição** - https://www.gov.br/inep/pt-br/acesso-a-informacao/dados-abertos/indicadores-educacionais/taxas-de-transicao
#
# Os indicadores de transição, equivalentemente denominados como indicadores de fluxo escolar, têm por objetivo informar sobre a trajetória do estudante na educação básica, que por sua vez, depende da estrutura organizacional dos programas de educação formal (sistemática), ou educação escolar
# , normalmente operacionalizada em níveis de ensino. Os níveis de ensino representam grandes etapas de progressão educativa em termos de complexidade do conteúdo educacional e estão relacionados aos estágios do desenvolvimento cognitivo do indivíduo, os quais estão associados à sua idade (maturação) biológica. Os níveis de ensino, portanto, constituem-se em um conjunto de categorias ordenadas, definidas em relação a gradações de
# experiências e conhecimentos, habilidades e competências projetadas para serem vivenciadas e aprendidas em um determinado programa educacional em uma determinada idade. Dessa forma, a trajetória do estudante no sistema de ensino, que pode ser regular (transição de séries de acordo com a idade do estudante sem repetência ou evasão) ou não, traz informações tanto sobre o nível de conhecimento agregado como sobre a eficiência dos sistemas de ensino sendo, portanto, objeto de estudo acadêmico e de análise de políticas públicas educacionais.
#
# Nesse conjunto de dados temos as seguintes variáveis:
#
# Ano : ano da matrícula / ano da próxima matrícula
# Região : norte, nordeste, centro-oeste, sudeste e sul
# UF : unidade federativa
# Código do município	: código ibge do município
# Nome do município : nome do município
# Localização	: total, urbana, rural
# Dependência Administrativa : total, pública, privada
# Taxa de Promoção - Ensino Fundamental - Total
# Taxa de Promoção - Ensino Fundamental - Anos Iniciais
# Taxa de Promoção - Ensino Fundamental - Anos Finais
# Taxa de Promoção - Ensino Fundamental - 1º Ano
# Taxa de Promoção - Ensino Fundamental - 2º Ano
# Taxa de Promoção - Ensino Fundamental - 3º Ano
# Taxa de Promoção - Ensino Fundamental - 4º Ano
# Taxa de Promoção - Ensino Fundamental - 5º Ano
# Taxa de Promoção - Ensino Fundamental - 6º Ano
# Taxa de Promoção - Ensino Fundamental - 7º Ano
# Taxa de Promoção - Ensino Fundamental - 8º Ano
# Taxa de Promoção - Ensino Fundamental - 9º Ano
# Taxa de Promoção - Ensino Médio - Total
# Taxa de Promoção - Ensino Médio - 1ª série
# Taxa de Promoção - Ensino Médio - 2ª série
# Taxa de Promoção - Ensino Médio - 3ª série
# Taxa de Repetência - Ensino Fundamental - Total
# Taxa de Repetência - Ensino Fundamental - Anos Iniciais
# Taxa de Repetência - Ensino Fundamental - Anos Finais
# Taxa de Repetência - Ensino Fundamental - 1º Ano
# Taxa de Repetência - Ensino Fundamental - 2º Ano
# Taxa de Repetência - Ensino Fundamental - 3º Ano
# Taxa de Repetência - Ensino Fundamental - 4º Ano
# Taxa de Repetência - Ensino Fundamental - 5º Ano
# Taxa de Repetência - Ensino Fundamental - 6º Ano
# Taxa de Repetência - Ensino Fundamental - 7º Ano
# Taxa de Repetência - Ensino Fundamental - 8º Ano
# Taxa de Repetência - Ensino Fundamental - 9º Ano
# Taxa de Repetência - Ensino Médio - Total
# Taxa de Repetência - Ensino Médio - 1ª série
# Taxa de Repetência - Ensino Médio - 2ª série
# Taxa de Repetência - Ensino Médio - 3ª série
# Taxa de Evasão - Ensino Fundamental - Total
# Taxa de Evasão - Ensino Fundamental - Anos Iniciais
# Taxa de Evasão - Ensino Fundamental - Anos Finais
# Taxa de Evasão - Ensino Fundamental - 1º Ano
# Taxa de Evasão - Ensino Fundamental - 2º Ano
# Taxa de Evasão - Ensino Fundamental - 3º Ano
# Taxa de Evasão - Ensino Fundamental - 4º Ano
# Taxa de Evasão - Ensino Fundamental - 5º Ano
# Taxa de Evasão - Ensino Fundamental - 6º Ano
# Taxa de Evasão - Ensino Fundamental - 7º Ano
# Taxa de Evasão - Ensino Fundamental - 8º Ano
# Taxa de Evasão - Ensino Fundamental - 9º Ano
# Taxa de Evasão - Ensino Médio - Total
# Taxa de Evasão - Ensino Médio - 1ª série
# Taxa de Evasão - Ensino Médio - 2ª série
# Taxa de Evasão - Ensino Médio - 3ª série
# Migração para EJA - Ensino Fundamental
# Migração para EJA - Ensino Fundamental - Total
# Migração para EJA - Ensino Fundamental - Anos Iniciais
# Migração para EJA - Ensino Fundamental - Anos Finais
# Migração para EJA - Ensino Fundamental - 1º Ano
# Migração para EJA - Ensino Fundamental - 2º Ano
# Migração para EJA - Ensino Fundamental - 3º Ano
# Migração para EJA - Ensino Fundamental - 4º Ano
# Migração para EJA - Ensino Fundamental - 5º Ano
# Migração para EJA - Ensino Fundamental - 6º Ano
# Migração para EJA - Ensino Fundamental - 7º Ano
# Migração para EJA - Ensino Fundamental - 8º Ano
# Migração para EJA - Ensino Fundamental - 9º Ano
# Migração para EJA - Ensino Médio - Total
# Migração para EJA - Ensino Médio - 1ª série
# Migração para EJA - Ensino Médio - 2ª série
# Migração para EJA - Ensino Médio - 3ª série
#
# **Produto Interno Bruto dos Municípios** - https://www.ibge.gov.br/estatisticas/economicas/contas-nacionais/9088-produto-interno-bruto-dos-municipios.html?=&t=resultados
#
# São apresentados, a preços correntes, os valores adicionados brutos da Agropecuária, da Indústria e dos Serviços, que constituem os três grandes setores de atividade econômica, além da Administração, defesa, educação e saúde públicas e seguridade social, devido à sua relevância na economia brasileira, bem como informações sobre os impostos, líquidos de subsídios, o PIB e o PIB per capita dos Municípios brasileiros.
#
# Nesse conjunto de dados temos as seguintes variáveis:
#
# Ano
# Código da Grande Região
# Nome da Grande Região
# Código da Unidade da Federação
# Sigla da Unidade da Federação
# Nome da Unidade da Federação
# Código do Município
# Nome do Município
# Região Metropolitana
# Código da Mesorregião
# Nome da Mesorregião
# Código da Microrregião
# Nome da Microrregião
# Código da Região Geográfica Imediata
# Nome da Região Geográfica Imediata
# Município da Região Geográfica Imediata
# Código da Região Geográfica Intermediária
# Nome da Região Geográfica Intermediária
# Município da Região Geográfica Intermediária
# Código Concentração Urbana
# Nome Concentração Urbana
# Tipo Concentração Urbana
# Código Arranjo Populacional
# Nome Arranjo Populacional
# Hierarquia Urbana
# Hierarquia Urbana (principais categorias)
# Código da Região Rural
# Nome da Região Rural
# Região rural (segundo classificação do núcleo)
# Amazônia Legal
# Semiárido
# Cidade-Região de São Paulo
# Valor adicionado bruto da Agropecuária, a preços correntes(R$ 1.000)
# Valor adicionado bruto da Indústria,a preços correntes(R$ 1.000)
# Valor adicionado bruto dos Serviços,a preços correntes - exceto Administração, defesa, educação e saúde públicas e seguridade social(R$ 1.000)
# Valor adicionado bruto da Administração, defesa, educação e saúde públicas e seguridade social, a preços correntes(R$ 1.000)
# Valor adicionado bruto total, a preços correntes(R$ 1.000)
# Impostos, líquidos de subsídios, sobre produtos, a preços correntes(R$ 1.000)
# Produto Interno Bruto, a preços correntes(R$ 1.000)
# Produto Interno Bruto per capita, a preços correntes(R$ 1,00)
# Atividade com maior valor adicionado bruto
# Atividade com segundo maior valor adicionado bruto
# Atividade com terceiro maior valor adicionado bruto
#
#
# **DTB - Divisão Territorial Brasileira** - https://www.ibge.gov.br/geociencias/organizacao-do-territorio/estrutura-territorial/23701-divisao-territorial-brasileira.html?=&t=downloads
#
# Apresenta a relação de subdistritos, distritos e municípios que compõem, a cada ano, a divisão territorial brasileira oficial. Os arquivos trazem igualmente os geocódigos e a hierarquia administrativa às quais essas unidades estão subordinadas.
#
# Nesse conjunto de dados temos as seguintes variáveis:
#
# UF
# Nome_UF
# Região Geográfica Intermediária
# Nome Região Geográfica Intermediária
# Região Geográfica Imediata
# Nome Região Geográfica Imediata
# Mesorregião Geográfica
# Nome_Mesorregião
# Microrregião Geográfica
# Nome_Microrregião
# Município
# Código Município Completo
# Nome_Município

# %% [markdown]
# ### Coleta
#
# Os arquivos foram baixados para o diretório da minha máquina local. Os arquivos das Taxas de Transição, da Divisão Territorial Brasileira e do PIB dos Municípios, estavam originalmente no formato xlsx. Foi feita a conversão dos mesmos para csv. Para os arquivos das Taxas de Transição foram retiradas algumas linhas inicias e finais pois as mesmas continham informações sem relevância para o trabalho em questão.

# %% [markdown]
# ![alternative text](files_local_machine.jpg)

# %% [markdown]
# Neste trabalho será utilizada a Gloogle Cloud.
#
# Foi criado o projeto **mvp-sprint-eng-dados-project** na Google Cloud.

# %% [markdown]
# ![alternative text](project_gcp_n.png)

# %% [markdown]
# Neste projeto foi criado o bucket **mvp-sprint-eng-dados-bucket**. Para criar o bucket foi utilizado o comando ``gsutil mb gs://mvp-sprint-eng-dados-bucket``. Para ele serão copiados os arquivos da máquina local.

# %% [markdown]
# ![alternative text](bucket_gcp.jpg)

# %% [markdown]
# Os arquivos foram copiados para o bucket através do Google Cloud SDK Shell a partir da máquina local. Para a cópia dos arquivos foi utilizado o comando ``gsutil cp *.* gs://mvp-sprint-eng-dados-bucket``.

# %% [markdown]
# ![alternative text](copy_files_gcp.jpg)

# %% [markdown]
# Podemos visualizar os arquivos copiados para o bucket na Google Cloud.
#
# Via linha de comando ``gcloud storage ls --recursive gs://mvp-sprint-eng-dados-bucket``.

# %% [markdown]
# ![alternative text](files_bucket_cmd_gcp.jpg)

# %% [markdown]
# Ou pela interface web.

# %% [markdown]
# ![alternative text](files_bucket_gcp_n.png)

# %% [markdown]
# ### Modelagem
#
# Optei por trabalhar com um modelo de dados flat por cada conceito.

# %% [markdown]
# ![alternative text](data_model_n.png)

# %% [markdown]
# Descrição dos objetos do modelo.
#
# **bolsa_familia_2014_2019**
# Valores referentes ao programa Bolsa Família repassados à macro região do município.
#
# | Atributo | Tipo | Descrição | Domínio |
# |---|---|---|---|
# |codigo_regiao |integer |Código da macro região do município |Valores inteiros com o mínimo igual a 110001 e máximo igual a 530010 |
# |ano |integer |Ano do pagamento do benefício |Valores inteiros com o mínimo igual a 2014 e máximo igual a 2019 |
# |media_qtd_familias_beneficiarias_bolsa_familia |double |Quantidade média de famílias beneficiárias do programa |Valores decimais representando a média de famílias beneficiárias do programa |
# |media_valor_repassado_bolsa_familia |double |Valor médio repassado a cada família beneficiária do programa |Valores decimais representando o valor médio repassado a cada família beneficiária do programa |
# |media_valor_medio_beneficio |double |Valor médio do benefício |Valores decimais representando o valor médio do benefício |
#
# Os dados foram obtidos a partir das união dos dados dos arquivos *bolsa_familia_2014.txt*, *bolsa_familia_2015.txt*, *bolsa_familia_2016.txt*, *bolsa_familia_2017.txt*, *bolsa_familia_2018.txt* e *bolsa_familia_2019.txt*, acessados através da url https://dados.gov.br/dados/conjuntos-dados/bolsa-familia---mi-social.
#
# **pib_municipios_2010_2020**
# PIB dos municípios.
#
# | Atributo | Tipo | Descrição | Domínio |
# |---|---|---|---|
# |ano |integer |Ano do PIB |Valores inteiros com o mínimo igual a 2010 e máximo igual a 2020 |
# |codigo_municipio |integer |Código do município |Valores inteiros com o mínimo igual a 1100015 e máximo igual a 5300108 |
# |codigo_regiao |integer |Código da macro região do município |Valores inteiros com o mínimo igual a 110001 e máximo igual a 530010 |
# |pib |string |PIB do município |String representando o valor do PIB |
# |pib_percapita |string |PIB per-capita do município |String representando o valor do PIB |
#
# Os dados foram obtidos a partir do arquivo *pib_municipios_2010_2020.csv*, acessados através da url https://www.ibge.gov.br/estatisticas/economicas/contas-nacionais/9088-produto-interno-bruto-dos-municipios.html?=&t=resultados.
#
# **relatorio_dtb_brasil_municipio**
# Relação de municípios.
#
# | Atributo | Tipo | Descrição | Domínio |
# |---|---|---|---|
# |uf |integer |Código numérico da unidade da federação |Valores inteiros com o mínimo igual a 11 e máximo igual a 53 |
# |nome_uf |string |Nome da unidade da federação |Valores string descrevendo o nome da unidade da federação |
# |codigo_regiao |integer |Código da macro região do município |Valores inteiros com o mínimo igual a 110001 e máximo igual a 530010 |
# |nome_regiao |string |Nome da macro região do município |Valores string descrevendo o nome da macro região |
# |codigo_municipio |integer |Código do município |Valores inteiros com o mínimo igual a 1100015 e máximo igual a 5300108 |
# |nome_municipio |string |Nome do município |Valores string descrevendo o nome do município |
#
# Os dados foram obtidos a partir do arquivo *relatorio_dtb_brasil_municipio.csv*, acessados através da url https://www.ibge.gov.br/geociencias/organizacao-do-territorio/estrutura-territorial/23701-divisao-territorial-brasileira.html?=&t=downloads.
#
# **tx_transicao_municipios_2014_2019**
# Indicadores de transição ou equivalentemente denominados como indicadores de fluxo escolar. Informam sobre a trajetória do estudante na educação básica.
#
# | Atributo | Tipo | Descrição | Domínio |
# |---|---|---|---|
# |ano |integer |Ano do indicador |Valores inteiros com o mínimo igual a 2014 e máximo igual a 2019 |
# |codigo_municipio |integer |Código do município |Valores inteiros com o mínimo igual a 1100015 e máximo igual a 5300108 |
# |tipo_local |string |Localização da escola |Rural, Urbana ou Total |
# |dependencia |string |Dependência administrativa da escola | Privada, Pública ou Total |
# |valor |decimal(5,2) |Valor da taxa de transição |Valores percentuais entre 0 e 100 |
# |tipo |string |Código da etapa de ensino |TXPRO_FUN, TXPRO_F14, TXPRO_F58, TXPRO_F00, TXPRO_F01, TXPRO_F02, TXPRO_F03, TXPRO_F04, TXPRO_F05, TXPRO_F06, TXPRO_F07, TXPRO_F08, TXPRO_MED, TXPRO_M01, TXPRO_M02, TXPRO_M03, TXREP_FUN, TXREP_F14, TXREP_F58, TXREP_F00, TXREP_F01, TXREP_F02, TXREP_F03, TXREP_F04, TXREP_F05, TXREP_F06, TXREP_F07, TXREP_F08, TXREP_MED, TXREP_M01, TXREP_M02, TXREP_M03, TXEVE_FUN, TXEVE_F14, TXEVE_F58, TXEVE_F00, TXEVE_F01, TXEVE_F02, TXEVE_F03, TXEVE_F04, TXEVE_F05, TXEVE_F06, TXEVE_F07, TXEVE_F08, TXEVE_MED, TXEVE_M01, TXEVE_M02, TXEVE_M03, TXEVM_FUN, TXEVM_F14, TXEVM_F58, TXEVM_F00, TXEVM_F01, TXEVM_F02, TXEVM_F03, TXEVM_F04, TXEVM_F05, TXEVM_F06, TXEVM_F07, TXEVM_F08, TXEVM_M03 |
#
# Os dados foram obtidos a partir da união dos arquivos *tx_transicao_municipios_2014_2015.csv*, *tx_transicao_municipios_2015_2016.csv*, *tx_transicao_municipios_2016_2017.csv*, *tx_transicao_municipios_2017_2018.csv*, *tx_transicao_municipios_2018_2019.csv*, *tx_transicao_municipios_2019_2020.csv*, acessados através da url https://www.gov.br/inep/pt-br/acesso-a-informacao/dados-abertos/indicadores-educacionais/taxas-de-transicao.
#
# **tx_transicao_municipios_tipo**
# Dados de apoio para os Indicadores de transição. Apresenta a relação código e descrição para uma etapa de ensino.
#
# | Atributo | Tipo | Descrição | Domínio |
# |---|---|---|---|
# |tipo |string |Código da etapa de ensino | TXPRO_FUN, TXPRO_F14, TXPRO_F58, TXPRO_F00, TXPRO_F01, TXPRO_F02, TXPRO_F03, TXPRO_F04, TXPRO_F05, TXPRO_F06, TXPRO_F07, TXPRO_F08, TXPRO_MED, TXPRO_M01, TXPRO_M02, TXPRO_M03, TXREP_FUN, TXREP_F14, TXREP_F58, TXREP_F00, TXREP_F01, TXREP_F02, TXREP_F03, TXREP_F04, TXREP_F05, TXREP_F06, TXREP_F07, TXREP_F08, TXREP_MED, TXREP_M01, TXREP_M02, TXREP_M03, TXEVE_FUN, TXEVE_F14, TXEVE_F58, TXEVE_F00, TXEVE_F01, TXEVE_F02, TXEVE_F03, TXEVE_F04, TXEVE_F05, TXEVE_F06, TXEVE_F07, TXEVE_F08, TXEVE_MED, TXEVE_M01, TXEVE_M02, TXEVE_M03, TXEVM_FUN, TXEVM_F14, TXEVM_F58, TXEVM_F00, TXEVM_F01, TXEVM_F02, TXEVM_F03, TXEVM_F04, TXEVM_F05, TXEVM_F06, TXEVM_F07, TXEVM_F08, TXEVM_M03|
# |descricao |string |Nome da etapa de ensino |Apresenta a descrição da Taxa de Promoção, Repetência e Evasão, e Migração para EJA; para o Ensino Fundamental - Total, Anos Iniciais, Finais, e 1º Ano ao 9º Ano; e para o Ensino Médio - Total, e 1ª série à 3ª série |
#
# Os dados foram gerados baseados nas informações do objeto **tx_transicao_municipios_2014_2019**.

# %% [markdown]
# ### Carga
#
# Para a execução das atividades de ETL será utilizada a ferramenta Dataproc do Google Cloud. Nela foi criado o cluster ``mvp-sprint-eng-dados-cluster``. Após a execução das atividades de ETL gravamos os gravamos os conjuntos de dados transformados em tabelas da ferramenta BigQuery.

# %% [markdown]
# ![alternative text](cluster_gcp.png)

# %% [markdown]
# A execução das atividades de ETL será feita através de scripts Python codificados no notebook ``mvp-sprint-eng-dados-notebook.ipynb``.

# %% [markdown]
# ![alternative text](notebook_gcp.png)

# %% [markdown]
# Inicialmente definimos algumas variáveis para configuração das atividades de ETL e persitência dos dados transformados, e a seguir fazemos a seguir fazemos a extração, transformação e carga dos conjuntos de dados. Para executar essas atividades utilizaremos a linguagem Python em conjunto com a ferramenta Spark.

# %%
bucket_path = "gs://mvp-sprint-eng-dados-bucket/"
big_query_dataset = "mvp-sprint-eng-dados-project.mvp_sprint_eng_dados_bq_dataset"

# %% [markdown]
# #### Conjunto de dados **Dados do Bolsa Família**

# %% [markdown]
# Definição de variáveis auxiliares para o processamento dos conjuntos de dados ``bolsa_familia_2014.txt``, ``bolsa_familia_2015.txt``, ``bolsa_familia_2016.txt``, ``bolsa_familia_2017.txt``, ``bolsa_familia_2018.txt`` e ``bolsa_familia_2019.txt``.

# %%
bolsa_familia_2014_path = bucket_path + "bolsa_familia_2014.txt"
bolsa_familia_2015_path = bucket_path + "bolsa_familia_2015.txt"
bolsa_familia_2016_path = bucket_path + "bolsa_familia_2016.txt"
bolsa_familia_2017_path = bucket_path + "bolsa_familia_2017.txt"
bolsa_familia_2018_path = bucket_path + "bolsa_familia_2018.txt"
bolsa_familia_2019_path = bucket_path + "bolsa_familia_2019.txt"

# %% [markdown]
# Carga do bucket para o cluster e criação do Dataframe Spark ``bolsa_familia_2014_2019_df``.

# %%
bolsa_familia_2014_2019_df = spark.read.option("inferSchema",True).option("header",True).csv(bolsa_familia_2014_path)
bolsa_familia_2014_2019_df = bolsa_familia_2014_2019_df.union(spark.read.option("inferSchema",True).option("header",True).csv(bolsa_familia_2015_path))
bolsa_familia_2014_2019_df = bolsa_familia_2014_2019_df.union(spark.read.option("inferSchema",True).option("header",True).csv(bolsa_familia_2016_path))
bolsa_familia_2014_2019_df = bolsa_familia_2014_2019_df.union(spark.read.option("inferSchema",True).option("header",True).csv(bolsa_familia_2017_path))
bolsa_familia_2014_2019_df = bolsa_familia_2014_2019_df.union(spark.read.option("inferSchema",True).option("header",True).csv(bolsa_familia_2018_path))
bolsa_familia_2014_2019_df = bolsa_familia_2014_2019_df.union(spark.read.option("inferSchema",True).option("header",True).csv(bolsa_familia_2019_path))

# %% [markdown]
# Execução de rotinas de transformação no dataframe ``bolsa_familia_2014_2019_df``.
#
# 1 - Criação da coluna ``valor_medio_beneficio``, atribuindo o resultado de (``valor_repassado_bolsa_familia`` / ``qtd_familias_beneficiarias_bolsa_familia``) a ela;
# 2 - Criação da coluna ``ano``, atribuindo a ela a parte do ano da coluna ``anomes``;
# 3 - Criação da coluna ``mes``, atribuindo a ela a parte do mes da coluna ``anomes``;
# 4 - Alteração do nome da coluna ``ibge`` para ``codigo_regiao``;
# 5 - Exclusão da coluna ``anomes``.

# %%
bolsa_familia_2014_2019_df = bolsa_familia_2014_2019_df.withColumn("valor_medio_beneficio", bolsa_familia_2014_2019_df.valor_repassado_bolsa_familia / bolsa_familia_2014_2019_df.qtd_familias_beneficiarias_bolsa_familia)
bolsa_familia_2014_2019_df = bolsa_familia_2014_2019_df.withColumn("ano", bolsa_familia_2014_2019_df.anomes.substr( 1, 4).cast("int"))
bolsa_familia_2014_2019_df = bolsa_familia_2014_2019_df.withColumn("mes", bolsa_familia_2014_2019_df.anomes.substr( 5, 2).cast("int"))
bolsa_familia_2014_2019_df = bolsa_familia_2014_2019_df.withColumnRenamed("ibge","codigo_regiao")
bolsa_familia_2014_2019_df = bolsa_familia_2014_2019_df.drop("anomes")

# %% [markdown]
# Salva o dataframe em uma tabela para executar algumas rotinas de transformação.

# %%
spark.sql("DROP TABLE IF EXISTS bolsa_familia_2014_2019_table")
bolsa_familia_2014_2019_df.write.saveAsTable("bolsa_familia_2014_2019_table")
# Out:
# ivysettings.xml file not found in HIVE_HOME or HIVE_CONF_DIR,/etc/hive/conf.dist/ivysettings.xml will be used
# 23/09/10 04:48:46 WARN SessionState: METASTORE_FILTER_HOOK will be ignored, since hive.security.authorization.manager is set to instance of HiveAuthorizerFactory.

# %% [markdown]
# Agrupa os registros por ``codigo_regiao`` e ``ano`` pois os registos do conjunto de dados estão subdivididos em ``codigo_regiao``, ``ano`` e ``mes``. O agrupamento gera os campos ``media_qtd_familias_beneficiarias_bolsa_familia``, ``media_valor_repassado_bolsa_familia`` e ``media_valor_medio_beneficio``, por ``codigo_regiao`` e ``ano``.

# %%
bolsa_familia_2014_2019_df = spark.sql('''
    select codigo_regiao, ano, sum(qtd_familias_beneficiarias_bolsa_familia)/count(qtd_familias_beneficiarias_bolsa_familia) media_qtd_familias_beneficiarias_bolsa_familia, sum(valor_repassado_bolsa_familia)/count(valor_repassado_bolsa_familia) media_valor_repassado_bolsa_familia, sum(valor_medio_beneficio)/count(valor_medio_beneficio) media_valor_medio_beneficio from bolsa_familia_2014_2019_table group by codigo_regiao, ano
    ''')

# %% [markdown]
# Como resultado final das operações temos o dataframe com a estrutura abaixo.

# %%
bolsa_familia_2014_2019_df.printSchema()
# Out:
# root
#  |-- codigo_regiao: integer (nullable = true)
#  |-- ano: integer (nullable = true)
#  |-- media_qtd_familias_beneficiarias_bolsa_familia: double (nullable = true)
#  |-- media_valor_repassado_bolsa_familia: double (nullable = true)
#  |-- media_valor_medio_beneficio: double (nullable = true)

# %% [markdown]
# #### Conjunto de dados **Produto Interno Bruto dos Municípios**

# %%
pib_municipios_2010_2020_path = bucket_path + "pib_municipios_2010_2020.csv"

# %%
pib_municipios_2010_2020_df = spark.read.option("inferSchema",True).option("header",True).option("delimiter",";").csv(pib_municipios_2010_2020_path)

# %%
pib_municipios_2010_2020_df = pib_municipios_2010_2020_df.drop("Código da Grande Região","Nome da Grande Região","Código da Unidade da Federação",
                                                               "Sigla da Unidade da Federação","Nome da Unidade da Federação",
                                                               "Região Metropolitana","Código da Mesorregião","Nome da Mesorregião",
                                                               "Código da Microrregião","Nome da Microrregião",
                                                               "Município da Região Geográfica Imediata","Código da Região Geográfica Intermediária",
                                                               "Nome da Região Geográfica Intermediária","Município da Região Geográfica Intermediária",
                                                               "Código Concentração Urbana","Nome Concentração Urbana","Tipo Concentração Urbana",
                                                               "Código Arranjo Populacional","Nome Arranjo Populacional","Hierarquia Urbana",
                                                               "Hierarquia Urbana (principais categorias)","Código da Região Rural","Nome da Região Rural",
                                                               "Região rural (segundo classificação do núcleo)","Amazônia Legal","Semiárido",
                                                               "Cidade-Região de São Paulo","Valor adicionado bruto da Agropecuária, a preços correntes(R$ 1.000)",
                                                               "Valor adicionado bruto da Indústria,a preços correntes(R$ 1.000)",
                                                               "Valor adicionado bruto dos Serviços,a preços correntes - exceto Administração, defesa, educação e saúde públicas e seguridade social(R$ 1.000)",
                                                               "Valor adicionado bruto da Administração, defesa, educação e saúde públicas e seguridade social, a preços correntes(R$ 1.000)",
                                                               "Valor adicionado bruto total, a preços correntes(R$ 1.000)",
                                                               "Impostos, líquidos de subsídios, sobre produtos, a preços correntes(R$ 1.000)",
                                                               "Atividade com maior valor adicionado bruto","Atividade com segundo maior valor adicionado bruto",
                                                               "Atividade com terceiro maior valor adicionado bruto","Nome do Município",
                                                               "Nome da Região Geográfica Imediata")

# %%
pib_municipios_2010_2020_df = pib_municipios_2010_2020_df.withColumnRenamed("Ano","ano").withColumnRenamed("Código do Município","codigo_municipio").withColumnRenamed("Código da Região Geográfica Imediata","codigo_regiao").withColumnRenamed("Produto Interno Bruto, a preços correntes(R$ 1.000)","pib").withColumnRenamed("Produto Interno Bruto per capita, a preços correntes(R$ 1,00)","pib_percapita")

# %%
pib_municipios_2010_2020_df.printSchema()
# Out:
# root
#  |-- ano: integer (nullable = true)
#  |-- codigo_municipio: integer (nullable = true)
#  |-- codigo_regiao: integer (nullable = true)
#  |-- pib: string (nullable = true)
#  |-- pib_percapita: string (nullable = true)

# %%
relatorio_dtb_brasil_municipio_path = bucket_path + "relatorio_dtb_brasil_municipio.csv"

# %%
relatorio_dtb_brasil_municipio_df = spark.read.option("inferSchema",True).option("header",True).option("delimiter",";").csv(relatorio_dtb_brasil_municipio_path)

# %%
relatorio_dtb_brasil_municipio_df = relatorio_dtb_brasil_municipio_df.drop("Região Geográfica Intermediária","Nome Região Geográfica Intermediária",
                                                                           "Mesorregião Geográfica","Nome_Mesorregião","Microrregião Geográfica",
                                                                           "Nome_Microrregião","Município","_c13","_c14","_c15","_c16","_c17","_c18")

# %%
relatorio_dtb_brasil_municipio_df = relatorio_dtb_brasil_municipio_df.withColumnRenamed("UF","uf").withColumnRenamed("Nome_UF","nome_uf").withColumnRenamed("Região Geográfica Imediata","codigo_regiao").withColumnRenamed("Nome Região Geográfica Imediata","nome_regiao").withColumnRenamed("Código Município Completo","codigo_municipio").withColumnRenamed("Nome_Município","nome_municipio")

# %%
relatorio_dtb_brasil_municipio_df.printSchema()
# Out:
# root
#  |-- uf: integer (nullable = true)
#  |-- nome_uf: string (nullable = true)
#  |-- codigo_regiao: integer (nullable = true)
#  |-- nome_regiao: string (nullable = true)
#  |-- codigo_municipio: integer (nullable = true)
#  |-- nome_municipio: string (nullable = true)

# %%
tx_transicao_municipios_2014_2015_path = bucket_path + "tx_transicao_municipios_2014_2015.csv"
tx_transicao_municipios_2015_2016_path = bucket_path + "tx_transicao_municipios_2015_2016.csv"
tx_transicao_municipios_2016_2017_path = bucket_path + "tx_transicao_municipios_2016_2017.csv"
tx_transicao_municipios_2017_2018_path = bucket_path + "tx_transicao_municipios_2017_2018.csv"
tx_transicao_municipios_2018_2019_path = bucket_path + "tx_transicao_municipios_2018_2019.csv"
tx_transicao_municipios_2019_2020_path = bucket_path + "tx_transicao_municipios_2019_2020.csv"

# %%
tx_transicao_municipios_2014_2019_df = spark.read.option("inferSchema",True).option("header",True).option("delimiter",";").csv(tx_transicao_municipios_2014_2015_path)
tx_transicao_municipios_2014_2019_df = tx_transicao_municipios_2014_2019_df.union(spark.read.option("inferSchema",True).option("header",True).option("delimiter",";").csv(tx_transicao_municipios_2015_2016_path))
tx_transicao_municipios_2014_2019_df = tx_transicao_municipios_2014_2019_df.union(spark.read.option("inferSchema",True).option("header",True).option("delimiter",";").csv(tx_transicao_municipios_2016_2017_path))
tx_transicao_municipios_2014_2019_df = tx_transicao_municipios_2014_2019_df.union(spark.read.option("inferSchema",True).option("header",True).option("delimiter",";").csv(tx_transicao_municipios_2017_2018_path))
tx_transicao_municipios_2014_2019_df = tx_transicao_municipios_2014_2019_df.union(spark.read.option("inferSchema",True).option("header",True).option("delimiter",";").csv(tx_transicao_municipios_2018_2019_path))
tx_transicao_municipios_2014_2019_df = tx_transicao_municipios_2014_2019_df.union(spark.read.option("inferSchema",True).option("header",True).option("delimiter",";").csv(tx_transicao_municipios_2019_2020_path))

# %%
spark.sql("DROP TABLE IF EXISTS tx_transicao_municipios_2014_2019_table")
tx_transicao_municipios_2014_2019_df.write.saveAsTable("tx_transicao_municipios_2014_2019_table")
# Out:
# 23/09/10 04:48:55 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %%
tx_transicao_municipios_2014_2019_df = spark.sql('''
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXPRO_FUN,',','.') as decimal(5,2)) as valor,'TXPRO_FUN' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXPRO_F14,',','.') as decimal(5,2)) as valor,'TXPRO_F14' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXPRO_F58,',','.') as decimal(5,2)) as valor,'TXPRO_F58' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXPRO_F00,',','.') as decimal(5,2)) as valor,'TXPRO_F00' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXPRO_F01,',','.') as decimal(5,2)) as valor,'TXPRO_F01' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXPRO_F02,',','.') as decimal(5,2)) as valor,'TXPRO_F02' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXPRO_F03,',','.') as decimal(5,2)) as valor,'TXPRO_F03' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXPRO_F04,',','.') as decimal(5,2)) as valor,'TXPRO_F04' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXPRO_F05,',','.') as decimal(5,2)) as valor,'TXPRO_F05' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXPRO_F06,',','.') as decimal(5,2)) as valor,'TXPRO_F06' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXPRO_F07,',','.') as decimal(5,2)) as valor,'TXPRO_F07' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXPRO_F08,',','.') as decimal(5,2)) as valor,'TXPRO_F08' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXPRO_MED,',','.') as decimal(5,2)) as valor,'TXPRO_MED' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXPRO_M01,',','.') as decimal(5,2)) as valor,'TXPRO_M01' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXPRO_M02,',','.') as decimal(5,2)) as valor,'TXPRO_M02' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXPRO_M03,',','.') as decimal(5,2)) as valor,'TXPRO_M03' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXREP_FUN,',','.') as decimal(5,2)) as valor,'TXREP_FUN' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXREP_F14,',','.') as decimal(5,2)) as valor,'TXREP_F14' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXREP_F58,',','.') as decimal(5,2)) as valor,'TXREP_F58' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXREP_F00,',','.') as decimal(5,2)) as valor,'TXREP_F00' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXREP_F01,',','.') as decimal(5,2)) as valor,'TXREP_F01' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXREP_F02,',','.') as decimal(5,2)) as valor,'TXREP_F02' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXREP_F03,',','.') as decimal(5,2)) as valor,'TXREP_F03' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXREP_F04,',','.') as decimal(5,2)) as valor,'TXREP_F04' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXREP_F05,',','.') as decimal(5,2)) as valor,'TXREP_F05' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXREP_F06,',','.') as decimal(5,2)) as valor,'TXREP_F06' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXREP_F07,',','.') as decimal(5,2)) as valor,'TXREP_F07' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXREP_F08,',','.') as decimal(5,2)) as valor,'TXREP_F08' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXREP_MED,',','.') as decimal(5,2)) as valor,'TXREP_MED' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXREP_M01,',','.') as decimal(5,2)) as valor,'TXREP_M01' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXREP_M02,',','.') as decimal(5,2)) as valor,'TXREP_M02' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXREP_M03,',','.') as decimal(5,2)) as valor,'TXREP_M03' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVE_FUN,',','.') as decimal(5,2)) as valor,'TXEVE_FUN' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVE_F14,',','.') as decimal(5,2)) as valor,'TXEVE_F14' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVE_F58,',','.') as decimal(5,2)) as valor,'TXEVE_F58' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVE_F00,',','.') as decimal(5,2)) as valor,'TXEVE_F00' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVE_F01,',','.') as decimal(5,2)) as valor,'TXEVE_F01' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVE_F02,',','.') as decimal(5,2)) as valor,'TXEVE_F02' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVE_F03,',','.') as decimal(5,2)) as valor,'TXEVE_F03' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVE_F04,',','.') as decimal(5,2)) as valor,'TXEVE_F04' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVE_F05,',','.') as decimal(5,2)) as valor,'TXEVE_F05' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVE_F06,',','.') as decimal(5,2)) as valor,'TXEVE_F06' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVE_F07,',','.') as decimal(5,2)) as valor,'TXEVE_F07' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVE_F08,',','.') as decimal(5,2)) as valor,'TXEVE_F08' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVE_MED,',','.') as decimal(5,2)) as valor,'TXEVE_MED' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVE_M01,',','.') as decimal(5,2)) as valor,'TXEVE_M01' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVE_M02,',','.') as decimal(5,2)) as valor,'TXEVE_M02' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVE_M03,',','.') as decimal(5,2)) as valor,'TXEVE_M03' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVM_FUN,',','.') as decimal(5,2)) as valor,'TXEVM_FUN' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVM_F14,',','.') as decimal(5,2)) as valor,'TXEVM_F14' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVM_F58,',','.') as decimal(5,2)) as valor,'TXEVM_F58' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVM_F00,',','.') as decimal(5,2)) as valor,'TXEVM_F00' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVM_F01,',','.') as decimal(5,2)) as valor,'TXEVM_F01' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVM_F02,',','.') as decimal(5,2)) as valor,'TXEVM_F02' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVM_F03,',','.') as decimal(5,2)) as valor,'TXEVM_F03' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVM_F04,',','.') as decimal(5,2)) as valor,'TXEVM_F04' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVM_F05,',','.') as decimal(5,2)) as valor,'TXEVM_F05' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVM_F06,',','.') as decimal(5,2)) as valor,'TXEVM_F06' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVM_F07,',','.') as decimal(5,2)) as valor,'TXEVM_F07' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVM_F08,',','.') as decimal(5,2)) as valor,'TXEVM_F08' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVM_MED,',','.') as decimal(5,2)) as valor,'TXEVM_MED' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVM_M01,',','.') as decimal(5,2)) as valor,'TXEVM_M01' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVM_M02,',','.') as decimal(5,2)) as valor,'TXEVM_M02' as tipo from tx_transicao_municipios_2014_2019_table union
    select cast(substring(ANO,1,4) as int) as ano,CO_MUNICIPIO as codigo_municipio,TIPOLOCA as tipo_local,DEPENDAD as dependencia,cast(replace(TXEVM_M03,',','.') as decimal(5,2)) as valor,'TXEVM_M03' as tipo from tx_transicao_municipios_2014_2019_table
    ''')

# %%
tx_transicao_municipios_2014_2019_df.printSchema()
# Out:
# root
#  |-- ano: integer (nullable = true)
#  |-- codigo_municipio: integer (nullable = true)
#  |-- tipo_local: string (nullable = true)
#  |-- dependencia: string (nullable = true)
#  |-- valor: decimal(5,2) (nullable = true)
#  |-- tipo: string (nullable = false)

# %%
tx_transicao_municipios_tipo = [
        ("TXPRO_FUN","Taxa de Promoção - Ensino Fundamental - Total"),
        ("TXPRO_F14","Taxa de Promoção - Ensino Fundamental - Anos Iniciais"),
        ("TXPRO_F58","Taxa de Promoção - Ensino Fundamental - Anos Finais"),
        ("TXPRO_F00","Taxa de Promoção - Ensino Fundamental - 1º Ano"),
        ("TXPRO_F01","Taxa de Promoção - Ensino Fundamental - 2º Ano"),
        ("TXPRO_F02","Taxa de Promoção - Ensino Fundamental - 3º Ano"),
        ("TXPRO_F03","Taxa de Promoção - Ensino Fundamental - 4º Ano"),
        ("TXPRO_F04","Taxa de Promoção - Ensino Fundamental - 5º Ano"),
        ("TXPRO_F05","Taxa de Promoção - Ensino Fundamental - 6º Ano"),
        ("TXPRO_F06","Taxa de Promoção - Ensino Fundamental - 7º Ano"),
        ("TXPRO_F07","Taxa de Promoção - Ensino Fundamental - 8º Ano"),
        ("TXPRO_F08","Taxa de Promoção - Ensino Fundamental - 9º Ano"),
        ("TXPRO_MED","Taxa de Promoção -  Ensino Médio - Total"),
        ("TXPRO_M01","Taxa de Promoção -  Ensino Médio - 1ª série"),
        ("TXPRO_M02","Taxa de Promoção -  Ensino Médio - 2ª série"),
        ("TXPRO_M03","Taxa de Promoção -  Ensino Médio - 3ª série"),
        ("TXREP_FUN","Taxa de Repetência - Ensino Fundamental - Total"),
        ("TXREP_F14","Taxa de Repetência - Ensino Fundamental - Anos Iniciais"),
        ("TXREP_F58","Taxa de Repetência - Ensino Fundamental - Anos Finais"),
        ("TXREP_F00","Taxa de Repetência - Ensino Fundamental - 1º Ano"),
        ("TXREP_F01","Taxa de Repetência - Ensino Fundamental - 2º Ano"),
        ("TXREP_F02","Taxa de Repetência - Ensino Fundamental - 3º Ano"),
        ("TXREP_F03","Taxa de Repetência - Ensino Fundamental - 4º Ano"),
        ("TXREP_F04","Taxa de Repetência - Ensino Fundamental - 5º Ano"),
        ("TXREP_F05","Taxa de Repetência - Ensino Fundamental - 6º Ano"),
        ("TXREP_F06","Taxa de Repetência - Ensino Fundamental - 7º Ano"),
        ("TXREP_F07","Taxa de Repetência - Ensino Fundamental - 8º Ano"),
        ("TXREP_F08","Taxa de Repetência - Ensino Fundamental - 9º Ano"),
        ("TXREP_MED","Taxa de Repetência -  Ensino Médio - Total"),
        ("TXREP_M01","Taxa de Repetência -  Ensino Médio - 1ª série"),
        ("TXREP_M02","Taxa de Repetência -  Ensino Médio - 2ª série"),
        ("TXREP_M03","Taxa de Repetência -  Ensino Médio - 3ª série"),
        ("TXEVE_FUN","Taxa de Evasão - Ensino Fundamental - Total"),
        ("TXEVE_F14","Taxa de Evasão - Ensino Fundamental - Anos Iniciais"),
        ("TXEVE_F58","Taxa de Evasão - Ensino Fundamental - Anos Finais"),
        ("TXEVE_F00","Taxa de Evasão - Ensino Fundamental - 1º Ano"),
        ("TXEVE_F01","Taxa de Evasão - Ensino Fundamental - 2º Ano"),
        ("TXEVE_F02","Taxa de Evasão - Ensino Fundamental - 3º Ano"),
        ("TXEVE_F03","Taxa de Evasão - Ensino Fundamental - 4º Ano"),
        ("TXEVE_F04","Taxa de Evasão - Ensino Fundamental - 5º Ano"),
        ("TXEVE_F05","Taxa de Evasão - Ensino Fundamental - 6º Ano"),
        ("TXEVE_F06","Taxa de Evasão - Ensino Fundamental - 7º Ano"),
        ("TXEVE_F07","Taxa de Evasão - Ensino Fundamental - 8º Ano"),
        ("TXEVE_F08","Taxa de Evasão - Ensino Fundamental - 9º Ano"),
        ("TXEVE_MED","Taxa de Evasão -  Ensino Médio - Total"),
        ("TXEVE_M01","Taxa de Evasão -  Ensino Médio - 1ª série"),
        ("TXEVE_M02","Taxa de Evasão -  Ensino Médio - 2ª série"),
        ("TXEVE_M03","Taxa de Evasão -  Ensino Médio - 3ª série"),
        ("TXEVM_FUN","Migração para EJA - Ensino Fundamental - Total"),
        ("TXEVM_F14","Migração para EJA - Ensino Fundamental - Anos Iniciais"),
        ("TXEVM_F58","Migração para EJA - Ensino Fundamental - Anos Finais"),
        ("TXEVM_F00","Migração para EJA - Ensino Fundamental - 1º Ano"),
        ("TXEVM_F01","Migração para EJA - Ensino Fundamental - 2º Ano"),
        ("TXEVM_F02","Migração para EJA - Ensino Fundamental - 3º Ano"),
        ("TXEVM_F03","Migração para EJA - Ensino Fundamental - 4º Ano"),
        ("TXEVM_F04","Migração para EJA - Ensino Fundamental - 5º Ano"),
        ("TXEVM_F05","Migração para EJA - Ensino Fundamental - 6º Ano"),
        ("TXEVM_F06","Migração para EJA - Ensino Fundamental - 7º Ano"),
        ("TXEVM_F07","Migração para EJA - Ensino Fundamental - 8º Ano"),
        ("TXEVM_F08","Migração para EJA - Ensino Fundamental - 9º Ano"),
        ("TXEVM_MED","Migração para EJA -  Ensino Médio - Total"),
        ("TXEVM_M01","Migração para EJA -  Ensino Médio - 1ª série"),
        ("TXEVM_M02","Migração para EJA -  Ensino Médio - 2ª série"),
        ("TXEVM_M03","Migração para EJA -  Ensino Médio - 3ª série")]

# %%
tx_transicao_municipios_tipo_df = spark.createDataFrame(data=tx_transicao_municipios_tipo).withColumnRenamed("_1","tipo").withColumnRenamed("_2","descricao")

# %%
tx_transicao_municipios_tipo_df.printSchema()
# Out:
# root
#  |-- tipo: string (nullable = true)
#  |-- descricao: string (nullable = true)

# %%
spark.conf.set('temporaryGcsBucket', 'mvp-sprint-eng-dados-bucket')

# %%
from google.cloud import bigquery
client_bq = bigquery.Client()

# %%
client_bq.delete_table(f'mvp-sprint-eng-dados-project.mvp_sprint_eng_dados_bq_dataset.tx_transicao_municipios_tipo_table', not_found_ok=True)

# %%
tx_transicao_municipios_tipo_df.write.format('bigquery') \
    .option('table', f'mvp-sprint-eng-dados-project.mvp_sprint_eng_dados_bq_dataset.tx_transicao_municipios_tipo_table') \
    .mode('append') \
    .save()

# %%
client_bq.delete_table(f'mvp-sprint-eng-dados-project.mvp_sprint_eng_dados_bq_dataset.tx_transicao_municipios_2014_2019_table', not_found_ok=True)

# %%
tx_transicao_municipios_2014_2019_df.write.format('bigquery') \
    .option('table', f'mvp-sprint-eng-dados-project.mvp_sprint_eng_dados_bq_dataset.tx_transicao_municipios_2014_2019_table') \
    .mode('append') \
    .save()

# %%
client_bq.delete_table(f'mvp-sprint-eng-dados-project.mvp_sprint_eng_dados_bq_dataset.relatorio_dtb_brasil_municipio_table', not_found_ok=True)

# %%
relatorio_dtb_brasil_municipio_df.write.format('bigquery') \
    .option('table', f'mvp-sprint-eng-dados-project.mvp_sprint_eng_dados_bq_dataset.relatorio_dtb_brasil_municipio_table') \
    .mode('append') \
    .save()

# %%
client_bq.delete_table(f'mvp-sprint-eng-dados-project.mvp_sprint_eng_dados_bq_dataset.pib_municipios_2010_2020_table', not_found_ok=True)

# %%
pib_municipios_2010_2020_df.write.format('bigquery') \
    .option('table', f'mvp-sprint-eng-dados-project.mvp_sprint_eng_dados_bq_dataset.pib_municipios_2010_2020_table') \
    .mode('append') \
    .save()

# %%
client_bq.delete_table(f'mvp-sprint-eng-dados-project.mvp_sprint_eng_dados_bq_dataset.bolsa_familia_2014_2019_table', not_found_ok=True)

# %%
bolsa_familia_2014_2019_df.write.format('bigquery') \
    .option('table', f'mvp-sprint-eng-dados-project.mvp_sprint_eng_dados_bq_dataset.bolsa_familia_2014_2019_table') \
    .mode('append') \
    .save()

# %% [markdown]
# ### Análise

# %% [markdown]
# #### Qualidade dos dados

# %% [markdown]
# #### Solução do problema
